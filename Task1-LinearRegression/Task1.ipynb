# %% [markdown]
# # 📊 Task 1: Linear Regression with Standardization
#
# Welcome to your first hands-on task in **Data Science & Machine Learning**! In this notebook, you will explore a real dataset, prepare it for modeling, and implement **Linear Regression** — first manually using linear algebra, then using `scikit-learn`.
#
# **Dataset:** `Student_Performance.csv` — records of students' study habits and their exam performance.
#
# **Target variable:** `Performance Index`
#
# ### 🗂️ Contents
# 0. Introduction
# 1. Exploratory Data Analysis (EDA)
# 2. Data Preprocessing
# 3. Data Split
# 4. Modeling (Manual Implementation)
# 5. Modeling with `scikit-learn`
# 6. Feedback
#
# ---

# %% [markdown]
# ## 0. Introduction
#
# In this section, we load the dataset and take a first look at its structure. No exercises here — just run the cells below.
#
# ### Importing the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Student_Performance.csv')

# %% [markdown]
# Let's view the raw dataset:

# %%
df

# %% [markdown]
# Let's inspect the data types and check for missing values at a glance:

# %%
df.info()

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)
#
# Before building any model, it's essential to understand the data you're working with. Answer the questions below to explore the dataset's size, types, and distributions.
#
# ### Questions

# %% [markdown]
# #### Question 1.1 — Dataset size
#
# How many records are in the dataset? And how many features?
#
# **💡 Hint:** Look for a DataFrame attribute that reports its dimensions directly, or a function that reports the number of rows in an iterable.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# df_rows = df.shape[0]
# df_columns = df.shape[1]
# -->

# %% [markdown]
# #### Question 1.2 — Data types
#
# What are the data types of each feature? Is there any feature with a different type than the rest? How could this affect the performance of a machine learning model, and how can we solve it?
#
# **💡 Hint:** Use `dtypes` of each column. Watch out for columns of type `object` — these usually hold text/categorical values, which most ML algorithms can't process directly. Think about what kind of transformation could turn them into numbers.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# df.dtypes
# -->

# %% [markdown]
# #### Question 1.3 — Missing values
#
# Is there any null values in the `Previous Scores` feature?
#
# **💡 Hint:** Pandas has built-in methods for detecting missing values across a single column or an entire DataFrame.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# df['Previous Scores'].isnull().sum()
# -->

# %% [markdown]
# #### Question 1.4 — Extracurricular activities count
#
# How many students had Extracurricular Activities (`Extracurricular Activities == "Yes"`)? What is their percentage among the overall students?
#
# **💡 Hint:** Filter the DataFrame using a boolean condition, then count the resulting rows — or look for a method that counts occurrences of each unique value in a column.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# EA_Yes = len(df[df['Extracurricular Activities'] == 'Yes'])
# print(f"The percent of students who participate in extracurricular activities is: {EA_Yes / len(df) * 100:.2f}%")
# -->

# %% [markdown]
# #### Question 1.5 — Visualizing the distribution
#
# Plot a bar chart that visualizes the distribution of the `Extracurricular Activities` feature.
#
# **💡 Hint:** First count how many times each category ("Yes"/"No") appears, then pass those counts to a plotting function such as `.plot(kind="bar")` or `plt.bar()`.

# %%
# Your code goes here
# 1. Extract the categories (index) and their respective counts (values)
counts = df["???"].value_counts()

# 2. Pass them directly into matplotlib's bar function
plt.bar(counts.index, counts.values, color=['RED', 'GREEN'])

# 3. Add labels
plt.title('Distribution of Extracurricular Activities')
plt.xlabel('Extracurricular Activities')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# # 1. Extract the categories (index) and their respective counts (values)
# counts = df["Extracurricular Activities"].value_counts()
#
# # 2. Pass them directly into matplotlib's bar function
# plt.bar(counts.index, counts.values, color=['RED', 'GREEN'])
#
# # 3. Add labels
# plt.title('Distribution of Extracurricular Activities')
# plt.xlabel('Extracurricular Activities')
# plt.ylabel('Number of Students')
# plt.show()
# -->

# %% [markdown]
# #### Question 1.5 _(BONUS)_ — Visualizing the distribution
#
# Plot a bar chart that visualizes the distribution of the `Performance Index` feature. Are they uniformly distributed?
#
# **💡 Hint:** The same code structure as Question 1.5.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
# <!--
# counts = df["Performance Index"].value_counts()
#
# plt.bar(counts.index, counts.values)
#
# plt.title('Distribution of Performance Index')
# plt.xlabel('Performance Index')
# plt.ylabel('Number of Students')
# plt.show()
# -->

# %% [markdown]
# #### Question 1.6 — Encoding categorical values
#
# Use the `map` method to convert the Yes/No values into numeric 0/1.
#
# **💡 Hint:** `Series.map()` accepts a dictionary describing how each original value should be replaced.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# my_dict = {'Yes': 1, 'No': 0}
#
# df['Extracurricular Activities'] = df['Extracurricular Activities'].map(my_dict)
# -->

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Data Preprocessing
#
# Now that you understand the dataset, let's prepare it for modeling.
#
# ### Questions

# %% [markdown]
# #### Question 2.1 — Copy the dataset
#
# Create a copy of the dataset called `df_normalized`.
#
# **💡 Hint:** Modifying a DataFrame directly can silently affect the original data if you're not careful. Look for a method that returns an independent copy.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# df_normalized = df.copy()
# -->

# %% [markdown]
# #### Question 2.2 — Normalization
#
# On the copy you just created, apply normalization so that all features range between 0 and 1.
#
# **💡 Hint:** This is known as **Min-Max scaling**. Recall the formula, applied column by column:
#
# $$x' = \frac{x - x_{min}}{x_{max} - x_{min}}$$

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# for column in df_normalized.columns:
#     min_value = df_normalized[column].min()
#     max_value = df_normalized[column].max()
#     df_normalized[column] = (df_normalized[column] - min_value) / (max_value - min_value)
# -->

# %% [markdown]
# #### Question 2.3 — Renaming columns
#
# Rewrite all feature names in lowercase, replacing spaces with underscores.
#
# **💡 Hint:** String methods such as `.str.lower()` and `.str.replace()` can be applied directly to `DataFrame.columns`.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# df_normalized.columns = df_normalized.columns.str.lower().str.replace(' ', '_')
#
# -->

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Data Split
#
# ### Questions

# %% [markdown]
# #### Question 3.1 — Features and target
#
# Set `y` to be the target `Performance Index`, while `X` is the rest of the features.
#
# **💡 Hint:** `y` should be a single column (a Series), while `X` should be all the other columns (a DataFrame). There are 3 solutions suggested. Use `.drop()` for excluding a column.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# # LVL1 Solution:
# y =df["performance_index"]
# x = df[["hours_studied",
#         "previous_scores",
#         "extracurricular_activities",
#         "sleep_hours",
#         "sample_question_papers_practiced"]]
#
#
# # LVL2 Solution:
# y = df["performance_index"]
# X = df.drop("performance_index")
#
#
# # LVL3 Solution:
# X = df[[col for col in df.columns if col != 'performance_index']]
# y = df[[col for col in df.columns if col == 'performance_index']]
# -->

# %% [markdown]
# #### Question 3.2 — Train/test split
#
# Use the `train_test_split` method to split the data, with 70% of it used for training.
#
# **💡 Hint:** This function lives in `sklearn.model_selection`. Pay attention to whether you specify `train_size` or `test_size`, and consider setting a `random_state` for reproducibility.
#
# _What is the purpose of `random_state` parameter?_

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# from sklearn.model_selection import train_test_split
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# -->

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Modeling
#
# Time to build your own Linear Regression model from scratch, using pure linear algebra.
#
# ### Questions

# %% [markdown]
# #### Question 4.1 — Manual Linear Regression (Normal Equation)
#
# Implement Linear Regression manually using the Normal Equation — this time including a **bias term** $b$ (the intercept).
#
# To incorporate the bias, augment $X$ with a column of ones so the bias is learned alongside the weights:
#
# $$X_b = [\,\mathbf{1} \;\; X\,] \qquad\qquad \begin{bmatrix} b \\ w \end{bmatrix} = (X_b^{T} X_b)^{-1} X_b^{T} y$$
#
# **💡 Hint:** Use `np.hstack` or `np.column_stack` to add a column of ones to `X` before applying the formula. Once solved, the first value of the resulting vector is your bias $b$, and the rest are the weights $w$.

# %% [markdown]
# ##### Question 4.1.1 — Representing data as `numpy` matrices
#
# use the method `.to_numpy()` with the training data
#
# **💡 Hint:** Don't miss to apply iy for both `X` and `y`.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# X_train_np = X_train.to_numpy()
# y_train_np = y_train.to_numpy()
# -->

# %% [markdown]
# ##### Question 4.1.2 — Creating the bias vector `b`
#
# Create a column of ones with the same number of rows as X_train. The expected output **must** be a vector
#
# **💡 Hint:** You may use the method `np.ones((length, width))`.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# X_length = X_train_np.shape[0]
# ones_train = np.ones((X_length, 1))
# -->

# %% [markdown]
# ##### Question 4.1.3 — merging `b` with `X`
#
# Augment X_train with the column of ones `b` at the front
#
# **💡 Hint:** You may use the method `np.hstack((matrix1, matrix2))`.
# **🛑 Warning:** make sure they have the same number of rows

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# X_b = np.hstack((ones_train, X_train_np))
# -->

# %% [markdown]
# ##### Question 4.1.4 — Apply the Normal Equation
#
# $$(X_b^ T  X_b)^{-1}  X_b^T  y$$
#
# **💡 Hint:** use the following methods:
# 1. `np.linalg.inv(A)`: to find the inverse of the matrix `A`
# 2. `A @ B`: to perform cross product between the two matrices `A` and `B`
# 3. `A.T`: to find the transpose of matrix `A`

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# weights_manual = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y_train_np
# -->

# %% [markdown]
# ##### Question 4.1.5 — Find `b` and `w`
#
# print the weights of the resulted matrix as well as the bias vector

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# bias = weights_manual[0]
# weights = weights_manual[1:]
#
# print(f"Learned Intercept (Bias b): {bias:.4f}")
# print(f"Learned Weights (w): {weights}")
# -->

# %% [markdown]
# #### Question 4.2 — Predicting on the test set
#
# Use the test data `X` and perform a dot product with the weights (and bias!) to get the predicted values $\hat{y}$.
#
# **💡 Hint:** Remember to augment your test set with a column of ones the same way you did for training, so the dimensions line up for the dot product. Equivalently, you can compute $\hat{y} = Xw + b$ directly if you keep $w$ and $b$ separate.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# X_test_np = X_test.to_numpy()
#
# ones_test = np.ones((X_test_np.shape[0], 1))
# X_test_b = np.hstack((ones_test, X_test_np))
#
# y_pred_manual = X_test_b @ weights_manual
# -->

# %% [markdown]
# #### Question 4.3 — Repeat with normalized data
#
# Repeat the same modeling process (fit + predict) using the normalized dataset from Section 2.
#
# **💡 Hint:** The steps are identical to Questions 4.1–4.2 — just swap in the normalized version of `X_train` / `X_test` / `y_train` / `y_test`.

# %%
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
#
# X_train_norm_np = X_train_norm.to_numpy()
# X_test_norm_np = X_test_norm.to_numpy()
#
# ones_train_norm = np.ones((X_train_norm_np.shape[0], 1))
# X_b_norm = np.hstack((ones_train_norm, X_train_norm_np))
# weights_manual_norm = np.linalg.inv(X_b_norm.T @ X_b_norm) @ X_b_norm.T @ y_train_np
#
# ones_test_norm = np.ones((X_test_norm_np.shape[0], 1))
# X_test_b_norm = np.hstack((ones_test_norm, X_test_norm_np))
# y_pred_manual_norm = X_test_b_norm @ weights_manual_norm
#
# print(f"Normalized Intercept (Bias): {weights_manual_norm[0]:.4f}")
# print(f"Normalized Weights: {weights_manual_norm[1:]}")
# -->

# %% [markdown]
# #### Question 4.4 — Evaluating with RMSE
#
# Instead of a simple ratio-based accuracy measure, implement the **Root Mean Squared Error (RMSE)** in pure Python to evaluate both models:
#
# $$RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(y_i - \hat{y}_i)^2}$$
#
# **💡 Hint:** Write a function that takes the true values and predicted values, loops through them (or uses a list comprehension) to compute the squared differences, averages them, then takes the square root. Try to avoid relying on numpy/sklearn built-ins here so you build the calculation step by step — the `math` module's `sqrt` function may help.

# %%
# Your code goes here
import math
def calculate_rmse(y_true, y_pred):

    return False

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# def calculate_rmse(y_true, y_pred):
#     y_true = list(y_true)
#     y_pred = list(y_pred)
#     n = len(y_true)
#
#     squared_errors = []
#     for i in range(n):
#         error = y_true[i] - y_pred[i]
#         squared_errors.append(error ** 2)
#
#     mean_squared_error = sum(squared_errors) / n
#     return math.sqrt(mean_squared_error)
#
# rmse_unscaled = calculate_rmse(y_test, y_pred_manual)
# rmse_normalized = calculate_rmse(y_test, y_pred_manual_norm)
#
# print(f"Manual Model RMSE (Unscaled Data): {rmse_unscaled:.4f}")
# print(f"Manual Model RMSE (Normalized Data): {rmse_normalized:.4f}")
# -->

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Modeling with `scikit-learn`
#
# ### Questions

# %% [markdown]
# #### Question 5.1 — Fit a sklearn model
#
# Use `scikit-learn` to create and fit a `LinearRegression` model on the same training data.
#
# **💡 Hint:** Import `LinearRegression` from `sklearn.linear_model`. The workflow is: instantiate → `.fit()` → `.predict()`.

# %%
from sklearn.linear_model import LinearRegression
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# from sklearn.linear_model import LinearRegression
#
# sklearn_model = LinearRegression()
#
# sklearn_model.fit(X_train, y_train)
# y_pred_sklearn = sklearn_model.predict(X_test)
# -->

# %% [markdown]
# #### Question 5.2 — Evaluate with RMSE
#
# Use the RMSE metric to measure the accuracy of the sklearn model, and compare it to your manual implementation.
#
# **💡 Hint:** You can reuse the RMSE function you wrote in Question 4.4, or explore `sklearn.metrics` for a built-in equivalent (e.g. `root_mean_squared_error`) to double-check your result.

# %%
from sklearn.metrics import root_mean_squared_error
# Your code goes here

# %% [markdown]
# *🔒 Double tap to see solution*
#
# <!--
# from sklearn.metrics import root_mean_squared_error
#
# rmse_sklearn = root_mean_squared_error(y_test, y_pred_sklearn)
# -->

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Feedback
#
# Please take a moment to reflect on this task honestly — your feedback helps us improve future lessons! Mark the column that best matches how you feel about each statement (e.g. with an `X` or `✅`).
#
# | Statement | 😖 Very bad | 🙁 Bad | 😐 Normal | 🙂 Good | 😄 Great |
# |---|:---:|:---:|:---:|:---:|:---:|
# | I understood the mathematical foundation of Linear Regression | | | | | |
# | I find it useful to explore data before modeling | | | | | |
# | I learned some new techniques in preprocessing the data | | | | | |
